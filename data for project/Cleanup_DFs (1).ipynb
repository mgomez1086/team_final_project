# %%
import pandas as pd
from IPython.display import display

# %%
df = pd.read_csv(filepath_or_buffer = 'C:\\Users\\seanc\\Downloads\\draftedPlayers20092017.csv')

# %%
print(display(df.head()))#df.columns
print(display(udf1.head()))#df.columns
print(df.columns)
# Out:
#     Season      School Conference  Games  GamesStarted  MinnutesPlayedPerGame  \
# 0  2016-17  Washington  Pac-12     25.0   25.0          35.7
# 1  2016-17  UCLA        Pac-12     36.0   36.0          35.1
# 2  2016-17  Duke        ACC        29.0   27.0          33.3
# 3  2016-17  Kansas      Big 12     35.0   35.0          30.8
# 4  2016-17  Kentucky    SEC        36.0   34.0          29.6
#
#    FieldGoalsPerGame  FieldGoalsAttemptedPerGame  FieldGoalPercentage  \
# 0  8.4                17.6                        0.476
# 1  5.3                9.5                         0.551
# 2  5.7                12.6                        0.452
# 3  6.3                12.3                        0.513
# 4  5.9                12.4                        0.479
#
#    2PointFieldGoalsPerGame     ...       TotalReboundsPerGame  AssistsPerGame  \
# 0  6.3                         ...       5.7                   5.9
# 1  3.0                         ...       6.0                   7.6
# ...

# %%
udf1 = pd.read_csv(filepath_or_buffer = 'C:\\Users\\seanc\\Downloads\\undraftedPlayersB20092017.csv')
udf2 = pd.read_csv(filepath_or_buffer = 'C:\\Users\\seanc\\Downloads\\undraftedPlayers20092017.csv')

# %%
udf1.columns
# Out:
# Index(['Split', 'School', 'Class', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG%',
#        '3PM', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST',
#        'STL', 'BLK', 'PF', 'TOV', 'PTS', 'Name', 'Link'],
#       dtype='object')

# %%
udf2.columns
# Out:
# Index(['Split', 'School', 'Class', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG%',
#        '3PM', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST',
#        'STL', 'BLK', 'PF', 'TOV', 'PTS', 'Name', 'Link'],
#       dtype='object')

# %%
udf1['DraftStatus'] = 'Undrafted'
udf2['DraftStatus'] = 'Undrafted'
df['DraftStatus'] = 'Drafted'

# %%
udf1.head
# Out:
# <bound method NDFrame.head of                  Split           School  Class  GP  GS   MIN  FGM   FGA  \
# 0    NCAA Season Stats           DePaul     Jr  30  30  28.0  3.9   9.8
# 1    NCAA Season Stats           DePaul     So  32  32  30.0  3.1   7.9
# 2    NCAA Season Stats           DePaul     Fr  31  25  29.4  3.5   9.4
# 3    NCAA Season Stats           DePaul     Sr  32  32  29.3  4.4  11.3
# 4    NCAA Season Stats             UCLA     Sr  36  36  30.0  5.4  11.8
# 5    NCAA Season Stats             UCLA     Jr  32  32  35.3  6.4  13.6
# 6    NCAA Season Stats             UCLA     So  36  36  33.9  3.9   9.4
# 7    NCAA Season Stats             UCLA     Sr  36  36  30.0  5.4  11.8
# 8    NCAA Season Stats             Duke     Sr  37  33  32.9  2.6   6.4
# 9    NCAA Season Stats             Duke     Jr  35  35  31.8  3.5   8.7
# 10   NCAA Season Stats             Duke     So  39  14  21.7  2.2   5.3
# 11   NCAA Season Stats             Duke     Fr  32   4   7.3  0.5   1.6
# ...

# %%
pd.set_option('display.max_colwidth', -1)
udf1['Season'] = udf1['Link'].apply(lambda x: str(str(x).replace('/By_Season/Per_Game',''))[len(str(str(x).replace('/By_Season/Per_Game','')))-4:])
udf1['Season'] = udf1['Season'].apply(lambda x : str(int(x)-1) + '-' + str(x).replace('20','') )
udf2['Season'] = udf2['Link'].apply(lambda x: str(str(x).replace('/By_Season/Per_Game',''))[len(str(str(x).replace('/By_Season/Per_Game','')))-4:])
udf2['Season'] = udf2['Season'].apply(lambda x : str(int(x)-1) + '-' + str(x).replace('20','') )
# Out:
#                Split  School Class  GP  GS   MIN  FGM   FGA    FG%  3PM  \
# 0  NCAA Season Stats  DePaul  Jr    30  30  28.0  3.9  9.8   0.395  0.9
# 1  NCAA Season Stats  DePaul  So    32  32  30.0  3.1  7.9   0.397  1.1
# 2  NCAA Season Stats  DePaul  Fr    31  25  29.4  3.5  9.4   0.366  1.2
# 3  NCAA Season Stats  DePaul  Sr    32  32  29.3  4.4  11.3  0.388  1.3
# 4  NCAA Season Stats  UCLA    Sr    36  36  30.0  5.4  11.8  0.453  2.1
#
#     ...     AST  STL  BLK   PF  TOV   PTS               Name  \
# 0   ...     3.5  0.7  0.3  2.7  2.5  12.6  Billy Garrett
# 1   ...     3.9  0.7  0.2  2.8  2.3  12.3  Billy Garrett
# 2   ...     3.0  0.9  0.1  3.0  2.2  12.4  Billy Garrett
# 3   ...     3.3  1.2  0.2  2.5  3.3  14.9  Billy Garrett
# 4   ...     2.8  0.7  0.2  1.8  2.0  14.1  Isaac Hamilton
#
#                                                                                      Link  \
# 0  https://basketball.realgm.com/player/Billy-Garrett/NCAA/41395/2016/By_Season/Per_Game
# ...

# %%
df = df.drop(columns=['Conference','2PointFieldGoalsPerGame','2PointFieldGoalsAttemptedPerGame' \
                 ,'2PointFieldGoalPercentage','StrengthOfSchedule'])

# %%
#udf1 = udf1.drop(columns=['Split','Class'])
#udf2 = udf2.drop(columns=['Split','Class'])
#udf1 = udf1.drop(columns=['Name'])
#udf2 = udf2.drop(columns=['Name'])

# %%
print(df.columns)
print(udf1.columns)
# Out:
# Index(['Season', 'School', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG%', '3PM',
#        '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS', 'Link', 'DraftStatus'],
#       dtype='object')
# Index(['School', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%',
#        'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'PF',
#        'TOV', 'PTS', 'Link', 'DraftStatus', 'Season'],
#       dtype='object')

# %%
df = df.rename(columns={'Games': 'GP', 'GamesStarted': 'GS','MinnutesPlayedPerGame':'MIN' \
                       ,'FieldGoalsPerGame':'FGM', 'FieldGoalsAttemptedPerGame':'FGA',\
                       'FieldGoalPercentage':'FG%', '3PointFieldGoalsPerGame':'3PM',\
                       '3PointFieldGoalsAttemptedPerGame':'3PA', '3PointFieldGoalPercentage':'3P%',\
                       'FreeThrowsPerGame':'FTM', 'FreeThrowsAttemptedPerGame':'FTA',\
                       'FreeThrowPercentage':'FT%', 'OffensiveReboundsPerGame':'ORB',\
                       'DefensiveReboundsPerGame':'DRB', 'TotalReboundsPerGame':'TRB', 'AssistsPerGame':'AST',\
                       'StealsPerGame':'STL', 'BlocksPerGame':'BLK', 'TurnoversPerGame':'TOV',\
                       'PersonalFoulsPerGame':'PF', 'PointsPerGame':'PTS', 'PlayerLink':'Link' })

# %%
df = df[['School', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%',
       'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'PF',
       'TOV', 'PTS', 'Link', 'DraftStatus', 'Season']]

# %%
print(df.columns)
print(udf1.columns)
print(udf2.columns)
# Out:
# Index(['School', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%',
#        'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'PF',
#        'TOV', 'PTS', 'Link', 'DraftStatus', 'Season'],
#       dtype='object')
# Index(['School', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%',
#        'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'PF',
#        'TOV', 'PTS', 'Link', 'DraftStatus', 'Season'],
#       dtype='object')
# Index(['School', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%',
#        'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'PF',
#        'TOV', 'PTS', 'Link', 'DraftStatus', 'Season'],
#       dtype='object')

# %%
udf2['Season'] = udf2['Link'].apply(lambda x: str(str(x).replace('/By_Season/Per_Game',''))[len(str(str(x).replace('/By_Season/Per_Game','')))-4:])
udf2['Season'] = udf2['Season'].apply(lambda x : str(int(x)-1) + '-' + str(x).replace('20','') )

# %%
alldf = pd.concat([df, udf1, udf2], ignore_index=True)

# %%
alldf.to_csv('C:\\Users\\seanc\\Downloads\\alldf.csv')
